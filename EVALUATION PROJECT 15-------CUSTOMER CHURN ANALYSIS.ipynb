# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('churnanalysis.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# NO Null-Value are Present in this DataSet

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# From this Heatmap we can clearly see that the there is no-color change in this Dataset and hence there is no nul value present in this Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# Here, we can see that most of the columns are in Object form and we cant use mathmatical functions on Object so we have to convert these into integers so that we can use maths fucntions

# %% [markdown]
# LETS DROP SOME COLUMNS AS THEY ARE NOT AFFECTING OUR END RESULT OF "CHURN"

# %%
df.drop(['customerID','gender'],axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-f1408967d3a6> in <module>
# ----> 1 df.drop(['customerID','gender'],axis=1, inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %% [markdown]
# We just removered 2 columns customerID and gender as they are putting no effect on CHURN

# %%
df.columns
# Out:
# Index(['SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# We have to convert object attributes into integer so that we can apply maths functions on them by using "label encoder"

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Partner']=le.fit_transform(df['Partner'].astype('str'))
df['Dependents']=le.fit_transform(df['Dependents'].astype('str'))
df['PhoneService']=le.fit_transform(df['PhoneService'].astype('str'))
df['MultipleLines']=le.fit_transform(df['MultipleLines'].astype('str'))
df['InternetService']=le.fit_transform(df['InternetService'].astype('str'))
df['OnlineSecurity']=le.fit_transform(df['OnlineSecurity'].astype('str'))
df['OnlineBackup']=le.fit_transform(df['OnlineBackup'].astype('str'))
df['DeviceProtection']=le.fit_transform(df['DeviceProtection'].astype('str'))
df['TechSupport']=le.fit_transform(df['TechSupport'].astype('str'))
df['StreamingTV']=le.fit_transform(df['StreamingTV'].astype('str'))
df['StreamingMovies']=le.fit_transform(df['StreamingMovies'].astype('str'))
df['Contract']=le.fit_transform(df['Contract'].astype('str'))
df['PaperlessBilling']=le.fit_transform(df['PaperlessBilling'].astype('str'))
df['PaymentMethod']=le.fit_transform(df['PaymentMethod'].astype('str'))
df['TotalCharges']=le.fit_transform(df['TotalCharges'].astype('str'))
df['Churn']=le.fit_transform(df['Churn'].astype('str'))

# %%
df.head() # We can see that all the object variable now changeded to interger
# Out:
#    SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  \
# 0              0        1           0       1             0              1
# 1              0        0           0      34             1              0
# 2              0        0           0       2             1              0
# 3              0        0           0      45             0              1
# 4              0        0           0       2             1              0
#
#    InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 0                0               0             2                 0
# 1                0               2             0                 2
# 2                0               2             2                 0
# 3                0               2             0                 2
# 4                1               0             0                 0
#
#    TechSupport  StreamingTV  StreamingMovies  Contract  PaperlessBilling  \
# ...

# %%
df.corr()
# Out:
#                   SeniorCitizen   Partner  Dependents    tenure  PhoneService  \
# SeniorCitizen          1.000000  0.016479   -0.211185  0.016567      0.008576
# Partner                0.016479  1.000000    0.452676  0.379697      0.017706
# Dependents            -0.211185  0.452676    1.000000  0.159712     -0.001762
# tenure                 0.016567  0.379697    0.159712  1.000000      0.008448
# PhoneService           0.008576  0.017706   -0.001762  0.008448      1.000000
# MultipleLines          0.146185  0.142410   -0.024991  0.343032     -0.020538
# InternetService       -0.032310  0.000891    0.044590 -0.030359      0.387436
# OnlineSecurity        -0.128221  0.150828    0.152166  0.325468     -0.015198
# OnlineBackup          -0.013632  0.153130    0.091015  0.370876      0.024105
# DeviceProtection      -0.021398  0.166330    0.080537  0.371105      0.003727
# TechSupport           -0.151268  0.126733    0.133524  0.322942     -0.019158
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# From this Heatmap we can see that light color boxes are highly(positvely) corelated and dark color boxes are negatively correlated or less corelated

# %%
df.dtypes #Every Columns is in interger form
# Out:
# SeniorCitizen         int64
# Partner               int32
# Dependents            int32
# tenure                int64
# PhoneService          int32
# MultipleLines         int32
# InternetService       int32
# OnlineSecurity        int32
# OnlineBackup          int32
# DeviceProtection      int32
# TechSupport           int32
# StreamingTV           int32
# StreamingMovies       int32
# Contract              int32
# PaperlessBilling      int32
# PaymentMethod         int32
# MonthlyCharges      float64
# TotalCharges          int32
# Churn                 int32
# dtype: object

# %%
sns.lineplot(df['DeviceProtection'],df['Churn'])
plt.show()

# %%
sns.lineplot(df['StreamingTV'],df['Churn'])
plt.show()

# %%
sns.lineplot(df['TechSupport'],df['Churn'])
plt.show()

# %%
sns.distplot(df['OnlineBackup'])
plt.show()

# %%
sns.distplot(df['MonthlyCharges'])
plt.show()

# %%
sns.barplot(df['MonthlyCharges'],df['Churn'])
plt.show()

# %%
sns.barplot(df['TotalCharges'],df['Churn'])
plt.show()

# %%
sns.pairplot(df)

# %%
plt.scatter(df['OnlineSecurity'],df['OnlineBackup'])
plt.show()

# %%
df.describe()
# Out:
#        SeniorCitizen      Partner   Dependents       tenure  PhoneService  \
# count    7043.000000  7043.000000  7043.000000  7043.000000   7043.000000
# mean        0.162147     0.483033     0.299588    32.371149      0.903166
# std         0.368612     0.499748     0.458110    24.559481      0.295752
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     9.000000      1.000000
# 50%         0.000000     0.000000     0.000000    29.000000      1.000000
# 75%         0.000000     1.000000     1.000000    55.000000      1.000000
# max         1.000000     1.000000     1.000000    72.000000      1.000000
#
#        MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# count    7043.000000      7043.000000     7043.000000   7043.000000
# mean        0.940508         0.872923        0.790004      0.906432
# std         0.948554         0.737796        0.859848      0.880162
# ...

# %% [markdown]
# Lets check for OUTLIERS, if they are present we have to remove them and check the outiers Visualy by using BoxPlot analysis

# %%
plt.boxplot(df['MultipleLines'])
plt.show()

# %%
plt.boxplot(df['OnlineSecurity'])
plt.show()

# %%
plt.boxplot(df['MonthlyCharges'])
plt.show()

# %%
sns.boxplot(df['TotalCharges'])
plt.show()

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
# array([[0.43991649, 1.03453023, 0.65401193, ..., 1.16032292, 0.39860759,
#         0.60102348],
#        [0.43991649, 0.96662231, 0.65401193, ..., 0.25962894, 0.94876238,
#         0.60102348],
#        [0.43991649, 0.96662231, 0.65401193, ..., 0.36266036, 1.64188328,
#         1.66382851],
#        ...,
#        [0.43991649, 1.03453023, 1.5290241 , ..., 1.1686319 , 0.13968008,
#         0.60102348],
#        [2.27315869, 1.03453023, 0.65401193, ..., 0.32033821, 0.31653445,
#         1.66382851],
#        [0.43991649, 0.96662231, 0.65401193, ..., 1.35896134, 1.13801338,
#         0.60102348]])

# %%
np.where(z>3)
# Out:
# (array([   0,    3,    7,   20,   27,   62,   81,   89,  103,  105,  107,
#          114,  116,  129,  131,  133,  168,  180,  185,  187,  206,  211,
#          215,  216,  217,  225,  236,  252,  255,  259,  260,  263,  272,
#          278,  303,  321,  324,  328,  348,  354,  358,  372,  376,  382,
#          387,  398,  424,  431,  435,  452,  465,  481,  488,  495,  498,
#          544,  569,  596,  610,  616,  620,  634,  660,  667,  669,  674,
#          677,  688,  716,  718,  735,  765,  776,  784,  790,  794,  813,
#          829,  843,  847,  859,  866,  873,  875,  877,  884,  893,  917,
#          934,  941,  943,  960,  973, 1011, 1018, 1037, 1050, 1051, 1053,
#         1072, 1110, 1119, 1122, 1144, 1146, 1150, 1161, 1169, 1182, 1204,
#         1221, 1225, 1242, 1255, 1257, 1271, 1278, 1298, 1311, 1326, 1331,
#         1333, 1334, 1340, 1349, 1352, 1365, 1379, 1402, 1407, 1416, 1452,
#         1479, 1480, 1481, 1500, 1506, 1513, 1519, 1560, 1562, 1581, 1584,
# ...

# %%
z[3][4]
# Out:
# 3.054010391622917

# %%
z[7040][4]
# Out:
# 3.054010391622917

# %%
z[3080][4]
# Out:
# 3.054010391622917

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#       SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  \
# 1                 0        0           0      34             1              0
# 2                 0        0           0       2             1              0
# 4                 0        0           0       2             1              0
# 5                 0        0           0       8             1              2
# 6                 0        0           1      22             1              2
# ...             ...      ...         ...     ...           ...            ...
# 7037              0        0           0      72             1              0
# 7038              0        1           1      24             1              2
# 7039              0        1           1      72             1              2
# 7041              1        1           0       4             1              2
# 7042              0        0           0      66             1              0
#
# ...

# %%
df.shape
# Out:
# (7043, 19)

# %% [markdown]
# Here, we can see that around 680 rows are deleted as Outliers and now we are left with 6391 rows only in our dataset

# %% [markdown]
# NOW, LETS DECIEDE OUR TARGET VARIABLE(Y) AND INDEPENDENT VARIABLE(X)

# %%
x=df1.iloc[:,0:18]
x
# Out:
#       SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  \
# 1                 0        0           0      34             1              0
# 2                 0        0           0       2             1              0
# 4                 0        0           0       2             1              0
# 5                 0        0           0       8             1              2
# 6                 0        0           1      22             1              2
# ...             ...      ...         ...     ...           ...            ...
# 7037              0        0           0      72             1              0
# 7038              0        1           1      24             1              2
# 7039              0        1           1      72             1              2
# 7041              1        1           0       4             1              2
# 7042              0        0           0      66             1              0
#
# ...

# %%
y=df1.iloc[:,-1]
y
# Out:
# 1       0
# 2       1
# 4       1
# 5       1
# 6       0
#        ..
# 7037    0
# 7038    0
# 7039    0
# 7041    1
# 7042    0
# Name: Churn, Length: 6361, dtype: int32

# %% [markdown]
# NOW, WE HAVE TO TRAIN OUR MODEL AS PER THE REQUIREMENT

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
max_acc_score=0
for r_state in range(10,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20, random_state=r_state)
    logr=LogisticRegression()
    logr.fit(x_train,y_train)
    predlogr=logr.predict(x_test)
    accscore=accuracy_score(y_test,predlogr)
    if(accscore>max_acc_score):
        max_acc_score=accscore
        final_r_state=r_state
print('')
print('The max accuracy score corresponing to the',final_r_state,'is',max_acc_score)
# Out:
# The max accuracy score corresponing to the 49 is 0.816967792615868

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=49)

# %%
logr.fit(x_train,y_train)
logr.score(x_train,y_train)
# Out:
# 0.7963836477987422

# %%
predlogr=logr.predict(x_test)
print('Accuracy Score=',accuracy_score(y_test,predlogr))
print(confusion_matrix(y_test,predlogr))
print(classification_report(y_test,predlogr))
# Out:
# Accuracy Score= 0.816967792615868
# [[854  97]
#  [136 186]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       951
#            1       0.66      0.58      0.61       322
#
#     accuracy                           0.82      1273
#    macro avg       0.76      0.74      0.75      1273
# weighted avg       0.81      0.82      0.81      1273

# %% [markdown]
# # CROSS VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
logr=LogisticRegression()
logrscores=cross_val_score(logr,x,y,cv=10)
print('SCORES=',logrscores)
print('Mean & STD:',logrscores.mean(),logrscores.std())
# Out:
# SCORES= [0.79434851 0.80345912 0.79874214 0.80345912 0.79874214 0.77830189
#  0.78930818 0.80345912 0.79245283 0.80974843]
# Mean & STD: 0.7972021464609066 0.00854303982538433

# %% [markdown]
# # TO SAVE THE BEST MODEL

# %%
from sklearn.externals import joblib

# %%
joblib.dump(logr,'logrfiles.obj')
# Out:
# ['logrfiles.obj']
